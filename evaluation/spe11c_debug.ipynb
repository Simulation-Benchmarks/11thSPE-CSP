# %% [markdown]
# # Debugging of SPE11C
# Purpose: Understand data format through plotting. Use Calgary1 and Geos1 as examples at time 600.
#
# Observations:
# - The default visualization does not show any artefacts.
# - The vw cut indicates artefacts for Calgary1 but not GEOS1.
# - Iterating through different cut indices for the uw plane shows clearly an abrupt jump in the data - note that the colorbars change for Calgary1 if suddenly negative or small values appear.

# %% [markdown]
# ## Default options GEOS1

# %%
# %matplotlib inline
# %run ../evaluation/spe11c_visualize_spatial_maps -g Geos1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 49
# Out:
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\geos1\spe11c_spatial_map_600y.csv.
# File spe11c_geos1_600y.png has been generated.

# %% [markdown]
# ## Default options Calgary1

# %%
# %matplotlib inline
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 49
# Out:
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\calgary1\spe11c_spatial_map_600y.csv.
# File spe11c_calgary1_600y.png has been generated.

# %% [markdown]
# ## VW plane view GEOS1

# %%
# %matplotlib inline
# %run ../evaluation/spe11c_visualize_spatial_maps -g Geos1 -f ../shared_folder/data/spe11c -t 600 -cp vw -idx 49
# Out:
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\geos1\spe11c_spatial_map_600y.csv.

# %% [markdown]
# ## VW plane view Calgary 1

# %%
# %matplotlib inline
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp vw -idx 49
# Out:
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\calgary1\spe11c_spatial_map_600y.csv.
# File spe11c_calgary1_600y.png has been generated.

# %% [markdown]
# ## idx = 49..55 for GEOS1

# %%
# %matplotlib inline
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 49
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 50
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 51
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 52
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 53
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 54
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 55
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 56
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 57
# %run ../evaluation/spe11c_visualize_spatial_maps -g GEOS1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 58
# Out:
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\geos1\spe11c_spatial_map_600y.csv.
# File spe11c_geos1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\geos1\spe11c_spatial_map_600y.csv.
# File spe11c_geos1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\geos1\spe11c_spatial_map_600y.csv.
# File spe11c_geos1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\geos1\spe11c_spatial_map_600y.csv.
# File spe11c_geos1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\geos1\spe11c_spatial_map_600y.csv.
# ...

# %% [markdown]
# ## idx=49..58 for Calgary1

# %%
# %matplotlib inline
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 49
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 50
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 51
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 52
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 53
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 54
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 55
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 56
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 57
# %run ../evaluation/spe11c_visualize_spatial_maps -g Calgary1 -f ../shared_folder/data/spe11c -t 600 -cp uw -idx 58
# Out:
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\calgary1\spe11c_spatial_map_600y.csv.
# File spe11c_calgary1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\calgary1\spe11c_spatial_map_600y.csv.
# File spe11c_calgary1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\calgary1\spe11c_spatial_map_600y.csv.
# File spe11c_calgary1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# Processing ../shared_folder/data/spe11c\calgary1\spe11c_spatial_map_600y.csv.
# File spe11c_calgary1_600y.png has been generated.
# Processing ../shared_folder/data/spe11c\tetratech2\spe11c_spatial_map_600y.csv.
# ...
